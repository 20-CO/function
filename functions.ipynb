# %% [markdown]
# # Theory Questions:

# %% [markdown]
# 1..**What is the difference between a function and a method in Python?**

# %% [markdown]
# *function are block of code which perform specific task in python
# and not associated with any object  *
#  *method are asociated with object and can't perform independently*
#
#  for example:

# %% [markdown]
# function

# %%
def greetings ():
  print('hi everyone')

# %%
greetings()
# Out:
# hi everyone

# %% [markdown]
# method

# %%
class myclass:
 def sayhello():
  print("Hello there!")

myclass.sayhello()
# Out:
# Hello there!

# %% [markdown]
# ---

# %% [markdown]
# 2.**Explain the concept of function arguments and parameters in Python.**

# %% [markdown]
# *function element are use to pass input to the function while calling , these arguments are use to perform specialtask and parameters are the variables inside the bracket for example;*

# %%
a=3
b=7
def addition(a,b):
  return a+b

# %%
addition(3,7)
# Out:
# 10

# %% [markdown]
# ---

# %% [markdown]
# 3.**What are the different ways to define and call a function in Python?**

# %% [markdown]
# *call by value and call by refrence are the ways to define functions for example:*

# %%
def function():
  print("call the function one time")

# %%
function()
# Out:
# call the function one time

# %% [markdown]
# ---

# %% [markdown]
# 4.**What is the purpose of the return statement in a Python function?**

# %% [markdown]
# *in return statement the output came out is tuple and it can use further for example:*

# %%
def student_id():
  name = input("please enter your name")
  college = input("please enter your college")

  return name,college

# %%
student_id()
# Out:
# please enter your namebhumika
# please enter your collegehindu
# ('bhumika', 'hindu')

# %% [markdown]
# ---

# %% [markdown]
# 5.**What are iterators in Python and how do they differ from iterables?**

# %% [markdown]
# an iterators is a object representing a strem of data and any user can itrate over it and iterables are the data structer that can capable for returning and it help user to iterate over other

# %% [markdown]
# ---

# %% [markdown]
# 6.**Explain the concept of generators in Python and how they are defined.**

# %% [markdown]
# *generator function are a way to create iteration in more consice and simple manner and yield keywords instent of returning value*
# for example:

# %%
def generative_ai():
  yield("python basic")
  yield("data type and structer")
  yield("functions")

  for syllabus in generative_ai():
    print(f"topics in :{syllabus}")

# %%
for syllabus in generative_ai():
    print(f"topics in :{syllabus}")
# Out:
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# topics in :functions
# topics in :python basic
# topics in :data type and structer
# ...

# %% [markdown]
# ---

# %% [markdown]
# 7.**What are the advantages of using generators over regular functions?**

# %% [markdown]
# *it dose not need to store all of the values in memory at one time which reduce the risk of running out of memory*

# %% [markdown]
# ---

# %% [markdown]
# 8.**What is a lambda function in Python and when is it typically used?**

# %% [markdown]
# *a lambda function in python is a concise way to create anonymous functions and typically used to defined filtering logic

# %%
add = lambda x,y :x+y
result = add(3,7)
print(result)
# Out:
# 10

# %% [markdown]
# ---

# %% [markdown]
# 9.**Explain the purpose and usage of the `map()` function in Python.**

# %% [markdown]
# *map function execute a specific function for each time of iterable or mainly use when it applied single transformation function to all the iterable elements
# for example: *

# %%
numbers_as_strings = ["11", "12", "13", "14", "15"]
numbers_as_integers = list(map(int, numbers_as_strings))
print(numbers_as_integers)
# Out:
# [11, 12, 13, 14, 15]

# %% [markdown]
# ---

# %% [markdown]
# 10.**What is the difference between `map()`, `reduce()`, and `filter()` functions in Python?**

# %% [markdown]
# * *map function in python execute a specific function for each timeof iterate*
# * *reduce function use to folding or reducing the elemrnt and it take two argument function*
# * *filter function use to filter element from an iterable base on some condition*

# %%
for map

# %%
l = [1,2,3,4,5]
def add(x):
  return x + 10

  list(map(add,l))

# %%
list(map(add,l))
# Out:
# [11, 12, 13, 14, 15]

# %% [markdown]
# ---

# %% [markdown]
# 11.**Using pen & Paper write the internal mechanism for sum operation using  reduce function on this given
# list:[47,11,42,13];**

# %% [markdown]
# ![IMG_20241222_205012 (1).jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ---
#
#
#
# ---
#
#
#
# ---

# %% [markdown]
# # Practical Questions:

# %% [markdown]
# 1.**Write a Python function that takes a list of numbers as input and returns the sum of all even numbers in
# the list**

# %%
def even_sum(number):
    sum = 0
    for n in number:
        if n%2 == 0:
         sum = sum+n

    return sum

# %%
even_sum([1,2,3,4,5,6,7,8])
# Out:
# 20

# %% [markdown]
# ---

# %% [markdown]
# 2.**Create a Python function that accepts a string and returns the reverse of that string.**

# %%
def reverse_string(s):
  return s [::-1]
input_string =("hello world")
reversed_string = reverse_string(input_string)
print (reversed_string)
# Out:
# dlrow olleh

# %% [markdown]
# ---

# %% [markdown]
# 3.**Implement a Python function that takes a list of integers and returns a new list containing the squares of
# each number**

# %%
l = [2,4,6,8,10,12]
def square(l):
    sq = []
    for i in l :
        sq.append(i**2)
    return sq

# %%
square(l)
# Out:
# [4, 16, 36, 64, 100, 144]

# %% [markdown]
# ---

# %% [markdown]
# 4.**Write a Python function that checks if a given number is prime or not from 1 to 200.**

# %%
for i in range (1,201):
  n=0
  for j in range (2,(i//2+1)):
    if i%j==0:
      n+=1
      break
    if n==0 and i!=1:
        print(i,end=',')
# Out:
# 5,7,7,9,11,11,11,11,13,13,13,13,13,15,17,17,17,17,17,17,17,19,19,19,19,19,19,19,19,21,23,23,23,23,23,23,23,23,23,23,25,25,25,27,29,29,29,29,29,29,29,29,29,29,29,29,29,31,31,31,31,31,31,31,31,31,31,31,31,31,31,33,35,35,35,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,37,39,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,41,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,43,45,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,47,49,49,49,49,49,51,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,53,55,55,55,57,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,59,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,61,63,65,65,65,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,67,69,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,71,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,73,
# ...

# %% [markdown]
# ---

# %% [markdown]
# 5.**Create an iterator class in Python that generates the Fibonacci sequence up to a specified number of
# terms.**

# %%
s = ("class in python")

# %%
for i in s:
  print(i)
# Out:
# c
# l
# a
# s
# s
#
# i
# n
#
# p
# y
# t
# h
# o
# n

# %% [markdown]
# ---

# %% [markdown]
# 6.**Write a generator function in Python that yields the powers of 2 up to a given exponent.**

# %%
def powers_of_2(exponent):
    for i in range(exponent + 1):
        yield 2 ** i

# %%
gen = powers_of_2(5)
for power in gen:
    print(power)
# Out:
# 1
# 2
# 4
# 8
# 16
# 32

# %% [markdown]
# ---

# %% [markdown]
# 7.**Implement a generator function that reads a file line by line and yields each line as a string.**

# %% [markdown]
# ---

# %% [markdown]
# 8.**Use a lambda function in Python to sort a list of tuples based on the second element of each tuple.**

# %% [markdown]
# ---

# %% [markdown]
# 9.**Write a Python program that uses `map()` to convert a list of temperatures from Celsius to Fahrenheit.**

# %%
celsius_temperatures = [0, 10, 20, 30, 40, 50]
fahrenheit_temperatures = list(map(lambda c: (9/5) * c + 32, celsius_temperatures))
print(fahrenheit_temperatures)
# Out:
# [32.0, 50.0, 68.0, 86.0, 104.0, 122.0]

# %% [markdown]
# ---

# %% [markdown]
# 10.**Create a Python program that uses `filter()` to remove all the vowels from a given string**.

# %%
input_string = ("the car and the bus are ofsame colour")

vowels = "aeiouAEIOU"

filtered_string =''.join(filter(lambda char: char not in vowels, input_string))

print(filtered_string)
# Out:
# th cr nd th bs r fsm clr

# %% [markdown]
# ---

# %% [markdown]
# 11.**Imagine an accounting routine used in a book shop. It works on a list with sublists, which look like this:**
